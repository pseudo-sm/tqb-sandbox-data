# %%
import pandas as pd

# %%
data = pd.read_csv("insurance.csv")

# %%
data.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1281 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1281.000000  1338.000000   1338.000000
# mean     39.207025    30.665012     1.094918  13270.422265
# std      14.049960     6.117285     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.220000     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.600000     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
data[(data["bmi"]>30.) & (data["age"]<30)].sort_values(by="bmi",ascending=False)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 1047   22    male  52.580         1    yes  southeast  44501.39820
# 847    23    male  50.380         1     no  southeast   2438.05520
# 930    26    male  46.530         1     no  southeast   2927.06470
# 1131   27    male  45.900         2     no  southwest   3693.42800
# ...   ...     ...     ...       ...    ...        ...          ...
# 471    18  female  30.115         0     no  northeast   2203.47185
# 984    20    male  30.115         5     no  northeast   4915.05985
# 732    24  female  30.100         3     no  southwest   4234.92700
# 1283   18    male  30.030         1     no  southeast   1720.35370
# 1196   19  female  30.020         0    yes  northwest  33307.55080
#
# [197 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data[data.bmi.isnull()]
# Out:
#      age     sex  bmi  children smoker     region      charges
# 110   54    male  NaN         1     no  northwest  10825.25370
# 111   55  female  NaN         2     no  southwest  11881.35800
# 112   37    male  NaN         0     no  southwest   4646.75900
# 113   21  female  NaN         0     no  northwest   2404.73380
# 114   52    male  NaN         3     no  northeast  11488.31695
# 115   60    male  NaN         0     no  northeast  30259.99556
# 116   58    male  NaN         0     no  southeast  11381.32540
# 117   29  female  NaN         1    yes  southeast  19107.77960
# 118   49  female  NaN         0     no  southeast   8601.32930
# 119   37  female  NaN         2     no  northwest   6686.43130
# 120   44    male  NaN         2     no  southwest   7740.33700
# 121   18    male  NaN         0     no  northeast   1705.62450
# 122   20  female  NaN         0     no  northwest   2257.47525
# 123   44    male  NaN         1    yes  northeast  39556.49450
# ...

# %%
sns.heatmap(data.isnull())

# %%
data.fillna(data.mean(),inplace=True)

# %%
# Out:
# asas
# asas
# asas
# asas
# asas

# %%
for i,row in data[data.bmi.isnull()].iterrows():
  data[data["age"]==row.age].fillna(data[data["age"]==row.age].bmi.mean(),inplace=True)

# %%
sns.heatmap(data.isnull())

# %%
sns.heatmap(data.corr(),annot=True)

# %%
data[data["smoker"]=='yes']["charges"].mean()
# Out:
# 32050.23183153285

# %%
data[data["smoker"]=='no']["charges"].mean()
# Out:
# 8434.268297856199

# %%
data_encode = pd.get_dummies(data=data,prefix="OHE_",prefix_sep="_",columns=["smoker","sex","region","children"])

# %%
data_encode
# Out:
#       age     bmi      charges  OHE__no  ...  OHE__2  OHE__3  OHE__4  OHE__5
# 0      19  27.900  16884.92400        0  ...       0       0       0       0
# 1      18  33.770   1725.55230        1  ...       0       0       0       0
# 2      28  33.000   4449.46200        1  ...       0       1       0       0
# 3      33  22.705  21984.47061        1  ...       0       0       0       0
# 4      32  28.880   3866.85520        1  ...       0       0       0       0
# ...   ...     ...          ...      ...  ...     ...     ...     ...     ...
# 1333   50  30.970  10600.54830        1  ...       0       1       0       0
# 1334   18  31.920   2205.98080        1  ...       0       0       0       0
# 1335   18  36.850   1629.83350        1  ...       0       0       0       0
# 1336   21  25.800   2007.94500        1  ...       0       0       0       0
# 1337   61  29.070  29141.36030        0  ...       0       0       0       0
#
# [1338 rows x 17 columns]

# %%
plt.rcParams["figure.figsize"] = [14,10]
plt.rcParams["font.size"] = 14
plt.rcParams["font.weight"] = "bold"

# %%
sns.heatmap(data_encode.corr(),annot=True)

# %%
import numpy as np

# %%
data_encode["charges"] = np.log(data_encode["charges"])

# %%
data_encode["charges"]
# Out:
# 0        9.734176
# 1        7.453302
# 2        8.400538
# 3        9.998092
# 4        8.260197
#           ...
# 1333     9.268661
# 1334     7.698927
# 1335     7.396233
# 1336     7.604867
# 1337    10.279914
# Name: charges, Length: 1338, dtype: float64

# %%
sns.heatmap(data_encode.corr(),annot=True)

# %%
from sklearn.model_selection import train_test_split

# %%
y = data_encode["charges"]
data_encode.drop("charges",axis=1,inplace=True) 
X = data_encode
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.8)

# %%
X_train.shape
# Out:
# (1003, 16)

# %%
y_train.shape
# Out:
# (1003,)

# %%
X_train
# Out:
#       age     bmi  OHE__no  OHE__yes  ...  OHE__2  OHE__3  OHE__4  OHE__5
# 68     40  36.190        1         0  ...       0       0       0       0
# 259    19  31.920        0         1  ...       0       0       0       0
# 426    38  27.265        1         0  ...       0       0       0       0
# 474    54  25.100        0         1  ...       0       1       0       0
# 839    59  31.350        1         0  ...       0       0       0       0
# ...   ...     ...      ...       ...  ...     ...     ...     ...     ...
# 1219   38  30.210        1         0  ...       0       1       0       0
# 626    36  28.880        1         0  ...       0       1       0       0
# 930    26  46.530        1         0  ...       0       0       0       0
# 387    50  25.365        1         0  ...       1       0       0       0
# 1214   27  31.255        1         0  ...       0       0       0       0
#
# [1003 rows x 16 columns]

# %%
X_train.shape[0]/data.shape[0]
# Out:
# 0.749626307922272

# %%
X_test.shape[0]/data.shape[0]
# Out:
# 0.25037369207772797

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
lr.score(X,y)
# Out:
# 0.7697607834942365

# %%
y_pred
# Out:
# array([ 9.60318424, 10.62152787,  8.49791115,  7.83576594,  9.59471977,
#         8.47670544,  8.70633397,  8.47280691,  8.77662448, 10.03000356,
#         9.93709334,  9.54559523,  8.15601768, 10.62997474,  9.483112  ,
#        11.08628991,  8.57185707,  8.27203597, 10.92221853,  9.16995109,
#         9.31625977, 10.10569312,  7.97475749,  9.02650666,  9.57047646,
#        11.24438773,  9.32159879,  9.48265236,  9.87275518,  8.71963029,
#         7.7004547 ,  8.2979914 ,  9.57237691,  7.97013283,  9.05234341,
#         9.60547721,  9.21450591,  9.67901436,  8.59767554,  8.11275829,
#         9.30264303, 11.20101665,  9.4933259 ,  8.92014416,  9.52626437,
#         8.42753844, 10.85102359, 10.51084214, 10.08658163,  9.08555937,
#         9.35440425,  9.53637981,  9.10517036,  9.56131168,  9.33142306,
#        10.37568602,  8.29288287, 10.52118154,  9.00739963,  8.5184626 ,
#         9.95314091,  8.06652087,  8.24726421,  9.01371448,  8.8229888 ,
# ...

# %%
y_test
# Out:
# 676      9.432347
# 254     10.623694
# 80       8.398683
# 464      7.397584
# 261      9.745972
#           ...
# 1216     8.597050
# 1090    10.637683
# 138     10.215474
# 48       9.443822
# 916      9.988487
# Name: charges, Length: 335, dtype: float64

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 0.20339686264721224

# %%
plt.scatter(X_test["age"],y_test,color="red")
plt.scatter(X_test["age"],y_pred,color="green")
plt.xtitle("age")
